# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#importing important library's

# %%
df=pd.read_csv('Dataset .csv') # load the dataset

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df['Cuisines']=df['Cuisines'].fillna(df['Cuisines'].mode()[0])

# %%
plt.figure(figsize=(16,6))
sns.scatterplot(df['Aggregate rating'])
# Out:
# <Axes: ylabel='Aggregate rating'>

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df[['Cuisines','City']]
# Out:
#                               Cuisines              City
# 0           French, Japanese, Desserts       Makati City
# 1                             Japanese       Makati City
# 2     Seafood, Asian, Filipino, Indian  Mandaluyong City
# 3                      Japanese, Sushi  Mandaluyong City
# 4                     Japanese, Korean  Mandaluyong City
# ...                                ...               ...
# 9546                           Turkish         ��stanbul
# 9547   World Cuisine, Patisserie, Cafe         ��stanbul
# 9548            Italian, World Cuisine         ��stanbul
# 9549                   Restaurant Cafe         ��stanbul
# 9550                              Cafe         ��stanbul
#
# [9551 rows x 2 columns]

# %%
top=df.groupby(['City','Cuisines']).size().reset_index(name='Count')

# %%
top.sort_values(by='Count')
# Out:
#            City                                           Cuisines  Count
# 3030  ��stanbul                    World Cuisine, Patisserie, Cafe      1
# 1583  New Delhi  Cafe, Italian, Lebanese, Continental, Mediterr...      1
# 1584  New Delhi            Cafe, Italian, Mexican, Salad, Desserts      1
# 1585  New Delhi                        Cafe, Italian, North Indian      1
# 1586  New Delhi                                       Cafe, Korean      1
# ...         ...                                                ...    ...
# 2144  New Delhi                              North Indian, Mughlai    207
# 1606  New Delhi                                            Chinese    228
# 1791  New Delhi                                          Fast Food    242
# 2022  New Delhi                              North Indian, Chinese    284
# 2010  New Delhi                                       North Indian    658
#
# [3031 rows x 3 columns]

# %%
citys=df['City'].value_counts().head(5).index

# %%
citys
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad'], dtype='object', name='City')

# %%
Top_5=top[top['City'].isin(citys)]

# %%
Top_5.sort_values(by='Count',ascending=False)
# Out:
#            City                                           Cuisines  Count
# 2010  New Delhi                                       North Indian    658
# 2022  New Delhi                              North Indian, Chinese    284
# 1791  New Delhi                                          Fast Food    242
# 1606  New Delhi                                            Chinese    228
# 2144  New Delhi                              North Indian, Mughlai    207
# ...         ...                                                ...    ...
# 1585  New Delhi                        Cafe, Italian, North Indian      1
# 1584  New Delhi            Cafe, Italian, Mexican, Salad, Desserts      1
# 1583  New Delhi  Cafe, Italian, Lebanese, Continental, Mediterr...      1
# 1581  New Delhi                           Cafe, Italian, Fast Food      1
# 2561      Noida                               Tibetan, Street Food      1
#
# [1607 rows x 3 columns]

# %%
import plotly.express as px

# %%
fig = px.scatter_mapbox(df, lat='Latitude', lon='Longitude', hover_name='City',hover_data=['Cuisines'], zoom=5, height=600)
fig.update_layout(mapbox_style="open-street-map")
fig.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(df[df['Aggregate rating']>4],x='City',y='Aggregate rating')
# Out:
# <Axes: xlabel='City', ylabel='Aggregate rating'>

# %%
dff=df[['Longitude','Latitude','Aggregate rating']].corr()

# %%
dff
# Out:
#                   Longitude  Latitude  Aggregate rating
# Longitude          1.000000  0.043207         -0.116818
# Latitude           0.043207  1.000000          0.000516
# Aggregate rating  -0.116818  0.000516          1.000000

# %%
df['Has Online delivery']=df['Has Online delivery'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
df['Has Table booking']=df['Has Table booking'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
df['Has Online delivery'].value_counts(normalize=True)
# Out:
# Has Online delivery
# 0    0.743378
# 1    0.256622
# Name: proportion, dtype: float64

# %%
#As we clearly see that there is only 25% Restaurant has online delivery.

# %%
df['Has Table booking'].value_counts(normalize=True)
# Out:
# Has Table booking
# 0    0.878756
# 1    0.121244
# Name: proportion, dtype: float64

# %%
#As we clearly see that there is only 12% Restaurant has table booking.

# %%
online=df[df['Has Online delivery']==1]

# %%
sns.barplot(online,x='Price range',y='City')
# Out:
# <Axes: xlabel='Price range', ylabel='City'>

# %%
df.groupby('City')['Price range'].agg(pd.Series.mode)
# Out:
# City
# Abu Dhabi               4
# Agra               [2, 3]
# Ahmedabad               3
# Albany                  1
# Allahabad               3
#                     ...
# Weirton                 2
# Wellington City         4
# Winchester Bay          2
# Yorkton                 2
# ��stanbul               3
# Name: Price range, Length: 141, dtype: object

# %%
df['Price range'].mode()[0]
# Out:
# 1

# %%
avg_price=df.groupby('Price range')['Aggregate rating'].mean()

# %%
rang_max=avg_price.idxmax()

# %%
sns.barplot(avg_price,palette=['blue','yellow','pink','red'])
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_15648\343713828.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='Price range', ylabel='Aggregate rating'>

# %%
for i in df['Restaurant Name']:
    Len=len(i)
    print(Len)
# Out:
# 16
# 16
# 22
# 4
# 11
# 12
# 10
# 7
# 40
# 8
# 16
# 31
# 16
# 10
# 23
# 13
# 24
# 10
# 26
# 23
# 14
# 29
# 11
# 19
# 24
# 5
# 14
# 10
# 7
# 8
# 14
# 12
# 8
# 11
# 8
# 10
# 6
# 18
# 7
# 10
# 4
# 26
# 21
# 19
# 4
# 9
# 4
# 9
# 18
# 10
# 17
# 22
# 13
# 16
# 12
# 14
# 10
# 7
# 21
# 10
# 17
# 17
# 24
# 30
# 11
# 9
# 19
# 15
# 18
# 16
# 17
# 10
# 19
# 9
# 5
# 7
# 16
# 13
# 11
# 15
# 6
# 24
# 27
# 19
# 13
# 29
# 30
# 30
# 11
# 29
# 12
# 27
# 14
# 28
# 17
# 17
# 19
# 26
# 27
# 35
# 13
# 15
# 15
# 17
# 21
# 9
# 18
# 9
# 19
# 7
# 33
# 34
# 10
# 4
# 10
# 24
# 9
# 16
# 12
# 17
# 17
# 12
# 23
# 33
# 18
# 15
# 16
# 15
# 19
# 18
# 18
# 39
# 15
# 20
# 22
# 9
# 14
# 16
# 13
# 7
# 22
# 12
# 28
# 17
# 19
# 8
# 29
# 24
# 20
# 31
# 19
# 9
# 21
# 17
# 19
# 4
# 37
# 10
# 27
# 19
# 22
# 15
# 7
# 15
# 8
# 9
# 28
# 16
# 27
# 14
# 14
# 20
# 18
# 8
# 12
# 23
# 26
# 14
# 5
# 21
# 17
# 10
# 7
# 22
# 14
# 11
# 22
# 20
# 22
# 26
# 18
# 11
# 14
# 25
# 28
# 36
# 21
# 22
# 32
# 28
# 18
# 8
# 15
# 8
# 28
# 13
# 10
# ...

# %%
df=df.drop('Address',axis=1)

# %%
df=df.drop('Restaurant ID',axis=1)

# %%
df=df.drop('Locality Verbose',axis=1)

# %%
df=df.drop('Locality',axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
df.head()
# Out:
#    Country Code   Longitude   Latitude                          Cuisines  \
# 0           162  121.027535  14.565443        French, Japanese, Desserts
# 1           162  121.014101  14.553708                          Japanese
# 2           162  121.056831  14.581404  Seafood, Asian, Filipino, Indian
# 3           162  121.056475  14.585318                   Japanese, Sushi
# 4           162  121.057508  14.584450                  Japanese, Korean
#
#    Average Cost for two  Has Table booking  Has Online delivery  \
# 0                  1100                  1                    0
# 1                  1200                  1                    0
# 2                  4000                  1                    0
# 3                  1500                  0                    0
# 4                  1500                  1                    0
#
#   Is delivering now Switch to order menu  Price range  Aggregate rating  \
# ...

# %%
df=df.drop('Currency',axis=1)

# %%
df=df.drop('Restaurant Name',axis=1)

# %%
df=df.drop('City',axis=1)

# %%
sns.scatterplot(x=df['Cuisines'],y=df['Aggregate rating'])
# Out:
# <Axes: xlabel='Cuisines', ylabel='Aggregate rating'>

# %%
df['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian                                             945
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
mlb = MultiLabelBinarizer()
cuisine_encoded = pd.DataFrame(mlb.fit_transform(df['Cuisines']), columns=mlb.classes_)

# %%
df = pd.concat([df, cuisine_encoded],axis=1)

# %%
df=df.drop(columns=['Cuisines'],axis=1)

# %%
df['Is delivering now']=df['Is delivering now'].apply(lambda x: 1 if x=='No' else 0)

# %%
df['Switch to order menu']=df['Switch to order menu'].apply(lambda x: 1 if x=='No' else 0)

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df=df.astype(int)

# %%
dff=df.corr()['Aggregate rating'].abs()

# %%
dff.sort_values(ascending=False).nlargest(30)
# Out:
# Aggregate rating         1.000000
# Rating text_Not rated    0.916985
# Rating color_White       0.916985
# Rating text_Very Good    0.440186
# Rating color_Green       0.440186
# Price range              0.435535
# Votes                    0.315492
# Country Code             0.291115
# Rating text_Good         0.265175
# Rating color_Yellow      0.265175
# Rating text_Excellent    0.222501
# Has Online delivery      0.206034
# Rating color_Orange      0.204104
# ,                        0.200586
# Has Table booking        0.187183
# A                        0.180213
# l                        0.177060
# f                        0.172192
# e                        0.167562
# c                        0.155232
# p                        0.144939
# Longitude                0.125778
# m                        0.122268
# h                        0.112763
# E                        0.106997
# T                        0.105356
# x                        0.101980
# ...

# %%
point=0.1
top=dff[dff>=point].index

# %%
df_top=df[top]

# %%
df_top
# Out:
#       Country Code  Longitude  Has Table booking  Has Online delivery  \
# 0              162        121                  1                    0
# 1              162        121                  1                    0
# 2              162        121                  1                    0
# 3              162        121                  0                    0
# 4              162        121                  1                    0
# ...            ...        ...                ...                  ...
# 9546           208         28                  0                    0
# 9547           208         29                  0                    0
# 9548           208         29                  0                    0
# 9549           208         29                  0                    0
# 9550           208         29                  0                    0
#
#       Price range  Aggregate rating  Votes  ,  A  E  ...  p  x  \
# ...

# %%
x=df_top.drop('Aggregate rating',axis=1)
y=df_top['Aggregate rating']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error

# %%
print('r2_score',r2_score(y_test,y_pred))
print('mae',mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.9504404070046016
# mae 0.19665575510724712

# %%
train_r2 = r2_score(y_train, lr.predict(x_train)) 
test_r2 = r2_score(y_test, lr.predict(x_test))

print(f'Training R²: {train_r2:.3f}')
print(f'Test R²: {test_r2:.3f}')
# Out:
# Training R²: 0.954
# Test R²: 0.950

# %%
rf=RandomForestRegressor(n_estimators=25,max_depth=7,random_state=15)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=7, n_estimators=25, random_state=15)

# %%
r_pred=rf.predict(x_test)

# %%
print('r2_score',r2_score(y_test,r_pred))
print('mae',mean_absolute_error(y_test,r_pred))
# Out:
# r2_score 0.9516129471362917
# mae 0.17784783251784325

# %%
#Hence RandomForestRegressor give more accuracy and less error as compare to other model.

# %%
## Here i'm read same dataset with different name.

# %%
data=pd.read_csv('Dataset .csv')

# %%
data['Cuisines']=data['Cuisines'].fillna(data['Cuisines'].mode()[0])

# %%
X=data.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False)

# %%
menu=(X[X>4.5].sort_values())

# %%
menu
# Out:
# Cuisines
# Cafe, Burger                                                4.55
# Kebab                                                       4.55
# American, Continental, Burger                               4.60
# Ramen, Japanese                                             4.60
# Mediterranean, Asian, Continental, North Indian, Arabian    4.60
#                                                             ...
# Italian, Bakery, Continental                                4.90
# World Cuisine                                               4.90
# American, BBQ, Sandwich                                     4.90
# Sunda, Indonesian                                           4.90
# Italian, Deli                                               4.90
# Name: Aggregate rating, Length: 87, dtype: float64

# %%
plt.figure(figsize=(20,40))
sns.barplot(x=menu.values,y=menu.index,hue=menu.index,palette='viridis')
plt.xlim(4,5)
plt.show()

# %%
best=data.nlargest(10,'Votes')[['Cuisines','Votes']]
best ## ITALIAN FOOD HAS HIGHER VOTES AND ALSO MAX RATING
# Out:
#                                                Cuisines  Votes
# 728                            Italian, American, Pizza  10934
# 735                              American, Burger, Cafe   9667
# 3994         Continental, American, Asian, North Indian   7931
# 2412                          Continental, North Indian   7574
# 739               European, Mediterranean, North Indian   6907
# 2414                              North Indian, Chinese   5966
# 743   Finger Food, North Indian, Italian, Continenta...   5705
# 2307              European, Mediterranean, North Indian   5434
# 736               North Indian, European, Mediterranean   5385
# 2411                              Chinese, North Indian   5288

# %%
sns.histplot(data['Aggregate rating'])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Count'>

# %%
import joblib

# %%
joblib.dump(rf,'Cognifyz.pkl')
# Out:
# ['Cognifyz.pkl']
